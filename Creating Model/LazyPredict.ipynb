# %% [markdown]
# # **📚 Installation**

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=DeprecationWarning)

import numpy as np
import pandas as pd

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, RobustScaler
from sklearn.model_selection import train_test_split

import lazypredict
from lazypredict.Supervised import LazyRegressor

# %% [markdown]
# # **📂 Data Import**

# %%
# Create a DataFrame from CSV data
result_df = pd.read_csv("FE_golf.csv")

# %% [markdown]
# # **🍽️ Pre-Processing**

# %%
# Approach Data
result_df_no_green = result_df[result_df['from_location_scorer'] != 'Green']

numeric_features = ["ISS", 
                    "ISC", 
                    "SSI", 
                    "CSI",
                    "shot",
                    "distance_to_pin",
                    "dist_from_edge",
                    "dist_from_center",
                    "pin_minus_edge", 
                    "Actual Yard",
                    "yardage",
                    "hole_completeness"]

categorical_features = ['round', 
                        'par_value', 
                        'lie',
                        'slope', 
                        'elevation', 
                        'non_putting_dist_from_center_bins',
                        'non_putting_dist_from_edge_bins',
                        'non_putting_distance_to_pin_bins', 
                        'around_the_green',
                        'side_of_hole', 
                        'dog_legs', 
                        'HCP',
                        'shot_type',
                        'from_location_scorer', 
                        'from_location_laser']

numeric_transformer = Pipeline(steps=[
    ("scaler", RobustScaler())
])

categorical_transformer = Pipeline(steps=[
    ("onehot", OneHotEncoder(handle_unknown="ignore", drop='first', sparse_output=False))
])

preprocessor = ColumnTransformer(transformers=[
    ("num_transform", numeric_transformer, numeric_features),
    ("cat_transform", categorical_transformer, categorical_features)
])

# %% [markdown]
# # **🔪 Split**

# %%
feature_cols = categorical_features + numeric_features
X = result_df.loc[:, feature_cols]

target_cols = ['strokes_to_hole_out']
y = result_df.loc[:, target_cols]

# Extract the columns for stratification
stratify_cols = ['non_putting_dist_from_center_bins','non_putting_distance_to_pin_bins','par_value']
stratify_data = result_df[stratify_cols]

X_train, X_valid, y_train, y_valid = train_test_split(X, y, train_size=0.8, test_size=0.2,random_state=42,stratify=stratify_data)

# Apply the preprocessor to the training and validation data
X_train_transformed = preprocessor.fit_transform(X_train)
X_valid_transformed = preprocessor.transform(X_valid)

# %% [markdown]
# # **🤖 Lazy Predict**

# %%
reg = LazyRegressor(verbose=0,ignore_warnings=False, custom_metric=None )

models,predictions = reg.fit(X_train_transformed, X_valid_transformed, y_train.values.ravel(), y_valid.values.ravel())

models
# Out:
#  76%|███████▌  | 32/42 [00:41<00:07,  1.38it/s]
# QuantileRegressor model failed to execute
# Solver interior-point is not anymore available in SciPy >= 1.11.0.
# 100%|██████████| 42/42 [01:02<00:00,  1.49s/it]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001507 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2545
# [LightGBM] [Info] Number of data points in the train set: 6528, number of used features: 69
# [LightGBM] [Info] Start training from score 2.509191
#                                             Adjusted R-Squared  \
# Model
# GradientBoostingRegressor                                 0.88
# HistGradientBoostingRegressor                             0.88
# LGBMRegressor                                             0.88
# RandomForestRegressor                                     0.87
# SVR                                                       0.86
# BayesianRidge                                             0.86
# RidgeCV                                                   0.86
# Ridge                                                     0.86
# NuSVR                                                     0.86
# BaggingRegressor                                          0.86
# TransformedTargetRegressor                                0.86
# LinearRegression                                          0.86
# XGBRegressor                                              0.86
# LassoLarsIC                                               0.86
# AdaBoostRegressor                                         0.86
# ExtraTreesRegressor                                       0.85
# LassoCV                                                   0.85
# LassoLarsCV                                               0.85
# ElasticNetCV                                              0.85
# HuberRegressor                                            0.85
# OrthogonalMatchingPursuitCV                               0.84
# OrthogonalMatchingPursuit                                 0.84
# MLPRegressor                                              0.84
# KNeighborsRegressor                                       0.83
# PoissonRegressor                                          0.83
# LinearSVR                                                 0.83
# TweedieRegressor                                          0.82
# GammaRegressor                                            0.81
# DecisionTreeRegressor                                     0.77
# ExtraTreeRegressor                                        0.76
# PassiveAggressiveRegressor                                0.67
# LarsCV                                                    0.66
# ElasticNet                                                0.50
# DummyRegressor                                           -0.05
# LassoLars                                                -0.05
# Lasso                                                    -0.05
# KernelRidge                                              -3.53
# GaussianProcessRegressor                                -34.14
# SGDRegressor                              -6188322664677644.00
# RANSACRegressor                      -317920830248471691264.00
# Lars                          -1623035396645686570962124800.00
#
#                                                      R-Squared  \
# Model
# GradientBoostingRegressor                                 0.88
# HistGradientBoostingRegressor                             0.88
# LGBMRegressor                                             0.88
# RandomForestRegressor                                     0.88
# SVR                                                       0.87
# BayesianRidge                                             0.87
# RidgeCV                                                   0.87
# Ridge                                                     0.87
# NuSVR                                                     0.87
# BaggingRegressor                                          0.87
# TransformedTargetRegressor                                0.87
# LinearRegression                                          0.87
# XGBRegressor                                              0.86
# LassoLarsIC                                               0.86
# AdaBoostRegressor                                         0.86
# ExtraTreesRegressor                                       0.86
# LassoCV                                                   0.86
# LassoLarsCV                                               0.86
# ElasticNetCV                                              0.86
# HuberRegressor                                            0.86
# OrthogonalMatchingPursuitCV                               0.85
# OrthogonalMatchingPursuit                                 0.85
# MLPRegressor                                              0.85
# KNeighborsRegressor                                       0.84
# PoissonRegressor                                          0.84
# LinearSVR                                                 0.83
# TweedieRegressor                                          0.83
# GammaRegressor                                            0.82
# DecisionTreeRegressor                                     0.78
# ExtraTreeRegressor                                        0.78
# PassiveAggressiveRegressor                                0.68
# LarsCV                                                    0.68
# ElasticNet                                                0.52
# DummyRegressor                                           -0.00
# LassoLars                                                -0.00
# Lasso                                                    -0.00
# KernelRidge                                              -3.32
# GaussianProcessRegressor                                -32.50
# SGDRegressor                              -5899964281774210.00
# RANSACRegressor                      -303106616208690053120.00
# Lars                          -1547406524698983981794721792.00
#
#                                            RMSE  Time Taken
# Model
# GradientBoostingRegressor                  0.42        5.22
# HistGradientBoostingRegressor              0.42        1.68
# LGBMRegressor                              0.42        0.23
# RandomForestRegressor                      0.43       16.87
# SVR                                        0.44        3.32
# BayesianRidge                              0.44        0.05
# RidgeCV                                    0.45        0.07
# Ridge                                      0.45        0.04
# NuSVR                                      0.45        5.21
# BaggingRegressor                           0.45        1.33
# TransformedTargetRegressor                 0.45        0.05
# LinearRegression                           0.45        0.05
# XGBRegressor                               0.45        0.32
# LassoLarsIC                                0.45        0.07
# AdaBoostRegressor                          0.46        0.74
# ExtraTreesRegressor                        0.46        4.89
# LassoCV                                    0.46        0.36
# LassoLarsCV                                0.46        0.23
# ElasticNetCV                               0.46        0.37
# HuberRegressor                             0.47        0.54
# OrthogonalMatchingPursuitCV                0.47        0.08
# OrthogonalMatchingPursuit                  0.47        0.05
# MLPRegressor                               0.48        3.07
# KNeighborsRegressor                        0.49        0.14
# PoissonRegressor                           0.49        0.04
# LinearSVR                                  0.50        1.84
# TweedieRegressor                           0.50        0.04
# GammaRegressor                             0.52        0.17
# DecisionTreeRegressor                      0.58        0.22
# ExtraTreeRegressor                         0.58        0.08
# PassiveAggressiveRegressor                 0.69        0.06
# LarsCV                                     0.69        0.38
# ElasticNet                                 0.85        0.04
# DummyRegressor                             1.23        0.03
# LassoLars                                  1.23        0.06
# Lasso                                      1.23        0.04
# KernelRidge                                2.55        3.43
# GaussianProcessRegressor                   7.10       10.66
# SGDRegressor                        94226322.12        0.05
# RANSACRegressor                  21357246331.21        0.37
# Lars                          48255826737247.31        0.05
