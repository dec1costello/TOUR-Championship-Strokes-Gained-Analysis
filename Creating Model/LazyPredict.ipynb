# %% [markdown]
# # **Installation**

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=DeprecationWarning)

import numpy as np
import pandas as pd

from sklearn.ensemble import StackingRegressor, GradientBoostingRegressor
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, RobustScaler
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_predict, cross_val_score

import lazypredict
from lazypredict.Supervised import LazyRegressor

# %% [markdown]
# # **Data Import**

# %%
# Create a DataFrame from CSV data
result_df = pd.read_csv("FE_golf.csv")

# %% [markdown]
# # **Lazy Predict**

# %%
numeric_features = ['distance_to_pin','dist_from_center','dist_from_edge','SSI','hole_completeness']

numeric_transformer = Pipeline(steps=[
    ("scaler", RobustScaler())
])

categorical_features = ["from_location_laser",'from_location_scorer','round','par_value','slope','elevation','dog_legs']

categorical_transformer = OneHotEncoder(handle_unknown="ignore")

preprocessor = ColumnTransformer(transformers=[
    ("num_transform", numeric_transformer, numeric_features),
    ("cat_transform", categorical_transformer, categorical_features)
])

#no greens
result_df_no_green = result_df[result_df['from_location_laser'] != 'Green']
result_df_no_green = result_df_no_green[result_df_no_green['from_location_laser'] != 'Right Rear Green Side Bunker']
result_df_no_green = result_df_no_green[result_df_no_green['from_location_scorer'] != 'Green']

feature_cols = ["from_location_laser",'from_location_scorer','round','par_value','slope','elevation','dog_legs','lie','distance_to_pin',"dist_from_center",'dist_from_edge','SSI','hole_completeness']
X = result_df.loc[:, feature_cols]

target_cols = ['strokes_to_hole_out']
y = result_df.loc[:, target_cols]

X_train, X_valid, y_train, y_valid = train_test_split(X, y, train_size=0.8, test_size=0.2,random_state=42)

reg = LazyRegressor(verbose=0,ignore_warnings=False, custom_metric=None )

models,predictions = reg.fit(X_train, X_valid, y_train.values.ravel(), y_valid.values.ravel())

models
# Out:
#  36%|███▌      | 15/42 [00:18<00:35,  1.31s/it]
# KNeighborsRegressor model failed to execute
# 'NoneType' object has no attribute 'split'
#  79%|███████▊  | 33/42 [00:34<00:05,  1.71it/s]
# QuantileRegressor model failed to execute
# Solver interior-point is not anymore available in SciPy >= 1.11.0.
# 100%|██████████| 42/42 [00:47<00:00,  1.14s/it]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000368 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1326
# [LightGBM] [Info] Number of data points in the train set: 6536, number of used features: 21
# [LightGBM] [Info] Start training from score 2.504131
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# GradientBoostingRegressor                    0.87       0.87  0.43        2.90
# ...

# %%
predictions
# Out:
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# GradientBoostingRegressor                    0.87       0.87  0.43        2.90
# LGBMRegressor                                0.86       0.86  0.44        0.18
# HistGradientBoostingRegressor                0.86       0.86  0.44        0.92
# MLPRegressor                                 0.85       0.85  0.45        5.32
# RandomForestRegressor                        0.85       0.85  0.45        8.96
# AdaBoostRegressor                            0.84       0.85  0.46        0.42
# XGBRegressor                                 0.84       0.84  0.46        0.33
# BaggingRegressor                             0.84       0.84  0.47        0.61
# ExtraTreesRegressor                          0.83       0.84  0.48        2.18
# SVR                                          0.83       0.83  0.48        3.85
# NuSVR                                        0.83       0.83  0.48        4.06
# ...
